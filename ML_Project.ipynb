# %% [markdown]
# <a href="https://colab.research.google.com/github/Oleg-Storozhev/AI_Univercity/blob/master/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 Настройка

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

sns.set(rc={'figure.figsize':(10, 8)})

# %%
file = '/content/drive/MyDrive/ML Project/train_music.csv'
size = sum(1 for l in open(file))
df = pd.read_csv(file, sep =',', skiprows=range(20000, size))
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-a66948ae77c8> in <module>()
#       1 file = '/content/drive/MyDrive/ML Project/train_music.csv'
# ----> 2 size = sum(1 for l in open(file))
#       3 df = pd.read_csv(file, sep =',', skiprows=range(20000, size))
#       4 df
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ML Project/train_music.csv'

# %%
df.info();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b759e4698a81> in <module>()
# ----> 1 df.info();
#
# NameError: name 'df' is not defined

# %%
df.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-174ba9bf1a5c> in <module>()
# ----> 1 df.describe(include='all')
#
# NameError: name 'df' is not defined

# %% [markdown]
#   Посмотрим сколько у нас пустых значений и где их больше всего

# %%
s = df.isna().sum()
s = s[s != 0].sort_values(ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
  print(s)
# Out:
# count_url_category_13                  19863
# count_url_category_15                  19740
# vol_app_3                              19733
# count_app_3                            19733
# count_url_category_12                  19655
# count_app_11                           19551
# vol_app_11                             19551
# count_app_13                           19465
# vol_app_13                             19465
# count_url_category_1                   19450
# vol_app_16                             19375
# count_app_16                           19375
# count_gift_type_4                      19368
# rr_gift_type_4                         19368
# vol_app_14                             19258
# count_app_14                           19258
# count_url_category_11                  19020
# service_9_flag_m3                      18977
# service_9_flag_m2                      18937
# service_9_flag_m1                      18909
# count_url_category_6                   18728
# ...

# %%
df
# Out:
#                 id  target  ...  data_type_3_m3  service_9_flag_m3
# 0      48104912810       0  ...     1292.468784                NaN
# 1       4851497268       0  ...        0.000053                NaN
# 2       4877823097       0  ...        0.000977                NaN
# 3       4830183791       0  ...        0.006680                NaN
# 4      48103940036       0  ...        0.002487                1.0
# ...            ...     ...  ...             ...                ...
# 19994   4898982828       0  ...        0.000795                NaN
# 19995   4850598495       1  ...      594.220917                NaN
# 19996   4877795542       0  ...     1759.344930                NaN
# 19997  48107114567       0  ...             NaN                NaN
# 19998   4836577305       0  ...      490.204814                NaN
#
# [19999 rows x 461 columns]
