# %% [markdown]
#     ЗАДАЧА 1. Промінь, який виходить з плоскопаралельної пластини, паралелен падаючому проміню. Товщина і показник заломлення матеріала пластини дорівнюють  𝑑  і  𝑛  відповідно. Знайти бокове зміщення проміня, який виходить з пластини.

# %% [markdown]
# Розв'язок
#
# нехай
# r – кут заломлення променя світла.
#
# Тоді, за формолою
#
# $$
# h = \frac{d*cosr}{sin(i-r)}
# $$
#
# Отримуємо
#
# $$
# d = \frac{h*sin(i-r)}{cosr}
# $$

# %% [markdown]
#     ЗАДАЧА 2. Монета лежить у фонтані на глибині h. На якій глибині вона здається для спостерігача, який дивиться у вертикальному напрямку зверху крізь поверхню води? Показники заломления води та повітря  𝑛𝑤=1,33  и  𝑛𝑎𝑖𝑟=1  відповідно.

# %% [markdown]
# $$h^{*} = \frac{h}{n_{w}}=\frac{h}{1,33}$$

# %% [markdown]
#     ЗАДАЧА 3. На поверхні водойми (показник заломлення  𝑛=1,33 ) плаває тонкий диск радіуса  𝑅 . До центра диска на дуже тонкої нитці на глибині  ℎ  підвішене важке грузило розміру  ≪𝑅 . При яких  ℎ  спостерігач на поверхні водойми матиме змогу побачити грузило?

# %% [markdown]
# $$\frac{sin(\beta)}{sin(\alpha)} = \frac{n_i}{1}$$
# $$sin(\alpha) = \frac{sin(\beta)}{n}$$
# $$sin(\alpha) = \frac{1}{n}$$
# $$cos(\alpha) = \frac{\sqrt{r-1}}{n}$$
# $$tg(\alpha) = \frac{1}{\sqrt{n^2-1}} = \frac{R}{h}$$
# $$h = R\sqrt{n^2-1}$$
# $$h \geq R\sqrt{n^2-1} = 0.877R$$

# %% [markdown]
#     ЗАДАЧА 4. Використовуючи принцип Ферма, для даного трикутника ABC побудуйте вписаний трикутник (всі вершини лежать на сторонах даного) периметр якого є мінімальним.

# %% [markdown]
# <img src="Tringle.gif" alt="Image">
#
# Спочатку відзначимо, що трикутники $A_{1}BC_{1}$ і $ABC$ подібні як такі, що загальний кут B і пропорційні боку, його укладають:
#
# $$
# cosB = \frac{BC_{1}}{BC} = \frac{A_{1}B}{AB}
# $$
#
# $\Delta AB_1C_1\sim \Delta ABC$ и $\Delta A_1B_1C \sim \Delta ABC$
#
# Зобразимо на рисунку рівні кути рівним числом дуг. Стає очевидним, що
# $\angle AA_1C_1 = \angle AA_1B_1;
# \angle BB_1C_1 = \angle A_1B_1B;
# \angle A_1C_1C = \angle B_1C_1C.$
#
# Тобто висоти трикутника $ABC$ є биссектрисами трикутника $A_1B_1C_1$
#
# Тепер уявімо, що сторони трикутника $АВС$ дзеркальні. Помістимо в точку $А_1$ точкове джерело світла і направимо один з його променів в точку $В_1$. Тоді відповідно до закону відбиття світла цей промінь потрапить в точку $С_1$ і далі повернеться у вихідну точку $А_1$. Бачимо, що в силу принципу Ферма периметр трикутника $A1B1C1$ буде найменшим. Бо, якщо взяти хоча б одну з точок A1B1C1 в інших місцях на сторонах $ВС$, $АС$, $АВ$ відповідно, то рівність хоча б однієї пари кутів - $АА_1С_1$ і $АА_1В_1$; $ВВ_1С_1$ і $А_1В_1В$; $А_1С_1С$ і $В_1С_1С$ - порушиться. Отже, світло тоді не піде по периметру трикутника $А_1У_1С_1$, а світловий промінь йде в оптично однорідному середовищі по найкоротшому шляху.

# %% [markdown]
#     ЗАДАЧА 5. Запішить функцію Лагранжа
#
# - матеріальної точки у однорідному полі тяжіння
# - матеріальної точки у полі сили Гука
# - математичного маятника
# - двох математичних маятників які з'єдані пружиною
#
# і побудуйте відповідні рівняння Ейлера-Лагранжа

# %% [markdown]
# 1) $m\ddot{x} = 0, m\ddot{y} = 0, m\ddot{z} = −mg +  \lambda \frac{\partial f}{\partial z}.$
# 2) $\ddot{\varphi} + \frac{g}{l}sin(\varphi) = 0$
# 3) $ $
# 4) $\frac{m_1}{2}(x_1^2+y_1^2)+\frac{m_2}{2}(x_2^2+y_2^2)-m_1gy_1-m_2gy_2$
#
#     $\frac{d}{dt} \frac{\partial L}{\partial \alpha_1} - \frac{d}{dt} \frac{\partial L}{\partial \alpha_1} = 0, i = 1,2$ - Элера-Лагранжа

# %% [markdown]
#     ЗАДАЧА 6. Задача Бернулі про брихістохрону

# %% [markdown]
# Введем декартову систему координат с центром в точке А, пусть точка В располагается, для определенности, в 4-м квадранте, ее координаты x1 > 0, y1 < 0.
#
# Проведем линию, соединяющую точки А и В, обозначим ее y = y(x).
#
# Всякой линии y = y(x), соединяющей точки А и В, сопоставим время спуска T по этой линии.
#
# Заметим, что в начальный момент времени t = 0, y(0) = 0 (тело находится в точке А), в момент окончания спуска тело попадает в точку В, следовательно, y(T) = y1.
#
# Скорость скатывания тела по дуге определяется выражением
#
# $$v(t)=\frac{ds}{dt}$$
# Отсюда
# $$dt = \frac{ds}{v(t)}$$
#
# Время спуска Т по всей линии вычисляется как сумма dt
#
# $$T = \int_{0}^{T}dt = \int_{y}^{}\frac{1}{v(t)}ds$$
#
# Дифференциал дуги можно вычислить
#
# $$ds = \sqrt{1+(y'(x))^2}dx$$
# $$y'(x)= \frac{dy}{dx}$$
#
# Итак, время спуска по кривой y(x) задается выражением:
#
# $$T = \int_{0}^{x_1}\frac{1}{v}\sqrt{1+(y'(x))^2}dx$$
#
# В этом выражении присутствует скорость тела v(x), ее нужно найти.
# $$\frac{mv^2}{2}-mgy = C$$
#
# В начальный момент времени скорость и высота равны 0, следовательно C = 0, поэтому:
#
# $$v = \sqrt{2gy}$$
#
# Подставим и получаем
#
# $$T = \frac{1}{\sqrt{2g}}\int_{0}^{x_1}\sqrt{\frac{1+(y'(x))^2}{y}}dx$$
#
# Итак, формально нужно найти минимум функционала (3) на кривых  удовлетворяющих условию:
#
# $$y(0)=0,y(x_1)=y_1$$
#
# Обозначим:
# $$F(y,y')=\sqrt{\frac{(1+y'(x))}{y}}$$
#
# Принцип Эйлера утверждает, что экстремальное значение функционала $\int F(y,y')dx$ является решением уравнения. Следовательно после элементарных вычислений получаем следующие уравнения линии y:
# $$x(t)=\frac{t-\frac{sin(2t)}{2}}{c}$$
# $$y(t)=\frac{1-cos(2t)}{2c}$$

# %% [markdown]
#     ЗАДАЧА 7. Для руха матеріальної точки у однородному полі тяжіння  𝑈=𝑚𝑔𝑧,𝑧>0 , виберіть декілька "можливих траєкторій" від A до B (з фіксованою енергією!). Порахуйте (чисельно) значення інтегралу Дії-Часу ( (4)  чи  (7) ) для таких траеєкторій. Переконайтесь що дійсна траеєкторія (парабола) є екстремаллю цього функціоналу. (виконати за допомогою IPython чи WM)

# %% [markdown]
# Решение в файле Task 7.np

# %% [markdown]
#     ЗАДАЧА 8. Для "природньої" метриці на сфері найменша відстань між двома точками A,B визначається як мінімальна довжина дуги великого кола яке проходить через ці точки (переріз площиною через центр O і A,B ). Покажіть, що така метрика є конформно еквівалентною евклидовій метриці на площині. Звідси визначіть показник заломлення  𝑛(𝐫)  відповідного середовища (на площині) та форму променів. Вказівка: встановить співвідношення між метриками на сфері та на площині скориставшись стереографічною проекцією див. рис.
# <img src="Задача.png" alt="Image">

# %% [markdown]
# <img src="photo_2021-10-10_20-44-54.jpg" alt="Image">
# $$l = \sqrt{x^2+y^2}$$
# $$l = 2Rtg(\varphi)$$
# $$dl = 2Rdtg(\varphi)$$
# $$dl = \frac{2Rd\varphi}{cos\varphi}$$
# $$dl = \frac{2RdS_{сферы}}{1+(\frac{l}{2R})^2}$$
# $$dS_{сферы} = \frac{dl}{1+(\frac{l}{2R})^2}$$
# $$\frac{dl}{dS_{сферы}} = \frac{dl}{\frac{dl}{1+(\frac{l}{2R})^2}} = 1+(\frac{l}{2R})^2 = k = n(l)$$
# где $n(l)$ - показатель приламления среды. Можно также записать $n(l) = 1+tg^2\varphi$
# $$M_1(\varepsilon, \eta,  \zeta )$$
# $$M_1'(x_1,y_1); M_2(x_2, y_2)$$
# любая дуга на $S$ (сфере) будет отображатся на $O_{1xy}$ (плоскости) на $M_1$, $M_2$. В случае $S_1 = S_2 = 0$ в окружности $M_1'O'M_2'$ c hflbecjv $OM_1' = 2OM_1$.
# То есть, показатель преломления зависит от координаты $\zeta$ для любой $M$ и от величины $R$. Причем $n(l)=1+tg\varphi \geq 1 \Rightarrow dl \geq dS_{сф} \forall M_1, M_2 = (\varepsilon_1 + d\varepsilon; \eta + d \eta, \zeta_1+d\zeta )$
#
# Отображение на плоскости $\zeta = 0$. Построим прямую через $M'(x,y,0), P(0,0,1)$
# $$\frac{\varepsilon}{x} = \frac{\eta}{y} = \frac{\zeta-1}{-1}$$
# $$\varepsilon = x(1-\zeta), \eta = y(1-\zeta)$$
# $$x = \frac{\varepsilon}{1-\zeta}, y = \frac{\eta}{1-\zeta}$$
# координаты M', при известном M
# $$\varepsilon = \frac{2x}{x^2+y^2+1}; \eta = \frac{2y}{x^2+y^2+1}; \zeta = \frac{x^2+y^2-1}{x^2+y^2+1}$$
# Координаты $М$ при известном $М'$
#
# Углы на $\zeta$ = углы на $\alpha$
#
# В случае отображения $\zeta = -1: x = \frac{2\varepsilon}{1-\zeta}; y = \frac{2\eta}{1-\zeta}$
